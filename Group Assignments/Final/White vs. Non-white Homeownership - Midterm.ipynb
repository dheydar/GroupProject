# %% [markdown]
# #  White vs. Non-white Homeownership in LA County
#
# This section applies a similar analysis to the one conducted for our second group assignment. While we previously focused on educational attainment (2014-2018) and household income (2018) within LA County, this section focuses on White vs. Non-White Homeownership in LA County (2018). All datasets were derived from Social Explorer.

# %%
import pandas as pd

# %%
whitehomeown = pd.read_csv('white vs. non-white homeownership/White vs. Non-white Homeownership.csv')

# %%
whitehomeown.shape
# Out:
# (2346, 60)

# %%
whitehomeown.head()
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037101110  14000US06037101110  Census Tract 1011.10
# 1  6037101122  14000US06037101122  Census Tract 1011.22
# 2  6037101210  14000US06037101210  Census Tract 1012.10
# 3  6037101220  14000US06037101220  Census Tract 1012.20
# 4  6037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  Geo_UGA  Geo_BTTR  \
# 0            0      ACSSF          3870     NaN  ...      NaN       NaN
# ...

# %%
whitehomeown.sample()
# Out:
#        Geo_FIPS           Geo_GEOID           Geo_NAME  \
# 646  6037217200  14000US06037217200  Census Tract 2172
#
#                                              Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 646  Census Tract 2172, Los Angeles County, California         ca         140
#
#      Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  Geo_UGA  Geo_BTTR  \
# 646            0      ACSSF          4516     NaN  ...      NaN       NaN
#
#      Geo_BTBG  Geo_PUMA5  Geo_PUMA1  SE_B10060_001  SE_B10060_002  \
# 646       NaN        NaN        NaN            399            140
#
#      SE_B10060_003  PCT_SE_B10060_002  PCT_SE_B10060_003
# 646            259              35.09              64.91
#
# [1 rows x 60 columns]

# %%
whitehomeown.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2346 non-null   int64
#  1   Geo_GEOID          2346 non-null   object
#  2   Geo_NAME           2346 non-null   object
#  3   Geo_QName          2346 non-null   object
#  4   Geo_STUSAB         2346 non-null   object
#  5   Geo_SUMLEV         2346 non-null   int64
#  6   Geo_GEOCOMP        2346 non-null   int64
#  7   Geo_FILEID         2346 non-null   object
#  8   Geo_LOGRECNO       2346 non-null   int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          2346 non-null   int64
#  14  Geo_COUNTY         2346 non-null   int64
#  15  Geo_COUSUB         0 non-null      float64
# ...

# %%
whitehomeown.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101210
# 3    6037101220
# 4    6037101300
# Name: Geo_FIPS, dtype: int64

# %%
whitehomeown = pd.read_csv(
    'white vs. non-white homeownership/White vs. Non-white Homeownership.csv',
    dtype={'Geo_FIPS':str})

# %%
whitehomeown['Geo_FIPS'] = whitehomeown['Geo_FIPS'].str.zfill(11)
whitehomeown.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  Geo_UGA  Geo_BTTR  \
# 0            0      ACSSF          3870     NaN  ...      NaN       NaN
# ...

# %%
whitehomeown.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2346 non-null   object
#  1   Geo_GEOID          2346 non-null   object
#  2   Geo_NAME           2346 non-null   object
#  3   Geo_QName          2346 non-null   object
#  4   Geo_STUSAB         2346 non-null   object
#  5   Geo_SUMLEV         2346 non-null   int64
#  6   Geo_GEOCOMP        2346 non-null   int64
#  7   Geo_FILEID         2346 non-null   object
#  8   Geo_LOGRECNO       2346 non-null   int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          2346 non-null   int64
#  14  Geo_COUNTY         2346 non-null   int64
#  15  Geo_COUSUB         0 non-null      float64
# ...

# %%
whitehomeown.columns[whitehomeown.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
whitehomeown = whitehomeown.dropna(axis=1,how="all")

# %%
whitehomeown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2346 non-null   object
#  1   Geo_GEOID          2346 non-null   object
#  2   Geo_NAME           2346 non-null   object
#  3   Geo_QName          2346 non-null   object
#  4   Geo_STUSAB         2346 non-null   object
#  5   Geo_SUMLEV         2346 non-null   int64
#  6   Geo_GEOCOMP        2346 non-null   int64
#  7   Geo_FILEID         2346 non-null   object
#  8   Geo_LOGRECNO       2346 non-null   int64
#  9   Geo_STATE          2346 non-null   int64
#  10  Geo_COUNTY         2346 non-null   int64
#  11  Geo_TRACT          2346 non-null   int64
#  12  SE_B10060_001      2346 non-null   int64
#  13  SE_B10060_002      2346 non-null   int64
#  14  SE_B10060_003      2346 non-null   int64
#  15  PCT_SE_B10060_002  2295 non-null   float64
# ...

# %%
whitehomeown.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_STATE  Geo_COUNTY  Geo_TRACT  \
# 0            0      ACSSF          3870          6          37     101110
# ...

# %%
columns_to_drop = ['Geo_GEOID','Geo_STUSAB','Geo_SUMLEV','Geo_GEOCOMP','Geo_FILEID','Geo_LOGRECNO']

# %%
whitehomeown = whitehomeown.drop(columns_to_drop,axis=1)
whitehomeown.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName  Geo_STATE  Geo_COUNTY  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...          6          37
# 1  Census Tract 1011.22, Los Angeles County, Cali...          6          37
# 2  Census Tract 1012.10, Los Angeles County, Cali...          6          37
# 3  Census Tract 1012.20, Los Angeles County, Cali...          6          37
# 4  Census Tract 1013, Los Angeles County, California          6          37
#
#    Geo_TRACT  SE_B10060_001  SE_B10060_002  SE_B10060_003  PCT_SE_B10060_002  \
# 0     101110            767            544            223              70.93
# 1     101122           1026            908            118              88.50
# ...

# %%
columns = list(whitehomeown)
columns
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_B10060_001',
#  'SE_B10060_002',
#  'SE_B10060_003',
#  'PCT_SE_B10060_002',
#  'PCT_SE_B10060_003']

# %%
whitehomeown.columns = ['FIPS',
 'Geo_NAME',
 'Geo_QName',
 'Geo_STATE',
 'Geo_COUNTY',
 'Geo_TRACT',
 'Owner Occupied Housing Units:',
 'White Alone, Not Hispanic or Latino Homeowners',
 'Non-White Homeowners',
 'PCT_White Alone, Not Hispanic or Latino Homeowners',
 'PCT_Non-White Homeowners']

# %%
whitehomeown.head()
# Out:
#           FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName  Geo_STATE  Geo_COUNTY  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...          6          37
# 1  Census Tract 1011.22, Los Angeles County, Cali...          6          37
# 2  Census Tract 1012.10, Los Angeles County, Cali...          6          37
# 3  Census Tract 1012.20, Los Angeles County, Cali...          6          37
# 4  Census Tract 1013, Los Angeles County, California          6          37
#
#    Geo_TRACT  Owner Occupied Housing Units:  \
# 0     101110                            767
# 1     101122                           1026
# 2     101210                            337
# 3     101220                            471
# 4     101300                           1268
#
# ...

# %%
whitehomeown['White Alone, Not Hispanic or Latino Homeowners'].head()
# Out:
# 0     544
# 1     908
# 2     289
# 3     247
# 4    1096
# Name: White Alone, Not Hispanic or Latino Homeowners, dtype: int64

# %%
whitehomeown['White Alone, Not Hispanic or Latino Homeowners'].mean()
# Out:
# 273.74552429667517

# %%
whitehomeown['Non-White Homeowners'].mean()
# Out:
# 371.8763853367434

# %%
whitehomeown['PCT_White Alone, Not Hispanic or Latino Homeowners'].mean()
# Out:
# 35.835511982570814

# %%
whitehomeown['PCT_Non-White Homeowners'].mean()
# Out:
# 64.16447930283219

# %%
whitehomeown['White Alone, Not Hispanic or Latino Homeowners'].describe()
# Out:
# count    2346.000000
# mean      273.745524
# std       333.761755
# min         0.000000
# 25%        24.250000
# 50%       137.000000
# 75%       420.750000
# max      2374.000000
# Name: White Alone, Not Hispanic or Latino Homeowners, dtype: float64

# %%
whitehomeown['White Alone, Not Hispanic or Latino Homeowners'].plot.hist(bins=50)

# %%
whitehomeown_sorted = whitehomeown.sort_values(by='White Alone, Not Hispanic or Latino Homeowners', ascending = False)

# %%
whitehomeown_sorted[['Geo_NAME','White Alone, Not Hispanic or Latino Homeowners']].head(10)
# Out:
#                   Geo_NAME  White Alone, Not Hispanic or Latino Homeowners
# 2166  Census Tract 8004.08                                            2374
# 1937  Census Tract 5776.03                                            2049
# 835   Census Tract 2626.04                                            2010
# 326   Census Tract 1397.02                                            1907
# 2152  Census Tract 8001.02                                            1810
# 2164  Census Tract 8003.32                                            1690
# 2103  Census Tract 6707.02                                            1687
# 2156  Census Tract 8003.24                                            1622
# 301   Census Tract 1352.03                                            1601
# 2205  Census Tract 9012.05                                            1504

# %%
whitehomeown_sorted2 = whitehomeown.sort_values(by='Non-White Homeowners', ascending = False)

# %%
whitehomeown_sorted2[['Geo_NAME','Non-White Homeowners']].head(10)
# Out:
#                   Geo_NAME  Non-White Homeowners
# 1705  Census Tract 5433.22                  1966
# 1701  Census Tract 5433.04                  1819
# 2235  Census Tract 9107.05                  1771
# 2148  Census Tract 7030.02                  1745
# 2150     Census Tract 7032                  1675
# 1997     Census Tract 6026                  1674
# 1711  Census Tract 5436.02                  1614
# 2149     Census Tract 7031                  1573
# 2197  Census Tract 9010.04                  1551
# 1144  Census Tract 4034.08                  1519

# %%
whitehomeown_sorted3 = whitehomeown.sort_values(by='PCT_White Alone, Not Hispanic or Latino Homeowners', ascending = False)

# %%
whitehomeown_sorted3[['Geo_NAME','PCT_White Alone, Not Hispanic or Latino Homeowners']].head(10)
# Out:
#                   Geo_NAME  PCT_White Alone, Not Hispanic or Latino Homeowners
# 2338  Census Tract 9800.26                                              100.0
# 1940     Census Tract 5991                                              100.0
# 1093  Census Tract 4019.01                                              100.0
# 536      Census Tract 2063                                              100.0
# 561   Census Tract 2089.03                                              100.0
# 624      Census Tract 2144                                              100.0
# 881   Census Tract 2699.05                                              100.0
# 2251  Census Tract 9108.11                                              100.0
# 634   Census Tract 2151.02                                              100.0
# 422   Census Tract 1908.01                                              100.0

# %%
import geopandas as gpd

# %%
tracts=gpd.read_file('../up206a/data/la_tracts.geojson')
tracts.head()
# Out:
#                   kind  external_id         name  \
# 0  Census Tract (2012)  06037101110  06037101110
# 1  Census Tract (2012)  06037101122  06037101122
# 2  Census Tract (2012)  06037101210  06037101210
# 3  Census Tract (2012)  06037101220  06037101220
# 4  Census Tract (2012)  06037101300  06037101300
#
#                             slug                                    set  \
# 0  06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1  06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2  06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 3  06037101220-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 4  06037101300-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
#
#                                             metadata  \
# 0  {'INTPTLAT': '+34.2594737', 'NAME': '1011.10',...
# 1  {'INTPTLAT': '+34.2677213', 'NAME': '1011.22',...
# 2  {'INTPTLAT': '+34.2529724', 'NAME': '1012.10',...
# ...

# %%
tracts.info(verbose=True,null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          2346 non-null   object
#  1   external_id   2346 non-null   object
#  2   name          2346 non-null   object
#  3   slug          2346 non-null   object
#  4   set           2346 non-null   object
#  5   metadata      2346 non-null   object
#  6   resource_uri  2346 non-null   object
#  7   geometry      2346 non-null   geometry
# dtypes: geometry(1), object(7)
# memory usage: 146.8+ KB

# %%
tracts = tracts[['name','geometry']]
tracts.head()
# Out:
#           name                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
tracts.columns = ['FIPS','geometry']

# %%
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
tracts.plot(figsize=(12,10))

# %%
tracts_whitehomeown=tracts.merge(whitehomeown,on="FIPS")

# %%
tracts_whitehomeown
# Out:
#              FIPS                                           geometry  \
# 0     06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1     06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2     06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3     06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4     06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...
# ...           ...                                                ...
# 2341  06037980031  MULTIPOLYGON (((-118.28530 33.70860, -118.2833...
# 2342  06037980033  MULTIPOLYGON (((-118.24463 33.71077, -118.2318...
# 2343  06037990100  MULTIPOLYGON (((-118.95114 33.99643, -118.9505...
# 2344  06037990200  MULTIPOLYGON (((-118.63168 34.00001, -118.6359...
# 2345  06037990300  MULTIPOLYGON (((-118.48228 33.74869, -118.4765...
#
#                   Geo_NAME                                          Geo_QName  \
# ...

# %%
tracts_whitehomeown.plot(figsize=(12,10),
                 column='PCT_White Alone, Not Hispanic or Latino Homeowners',
                 legend=True, 
                 scheme='NaturalBreaks')

# %%
tracts_whitehomeown.plot(figsize=(12,10),
                 column='PCT_Non-White Homeowners',
                 legend=True, 
                 scheme='NaturalBreaks')
